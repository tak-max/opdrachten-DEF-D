# %% [markdown]
# # Krachtactuator Ontwerpopdracht
#
# In de eerste 4 weken van het vak DEF-D hebben jullie simulaties gedaan van verschillende opstellingen in de electrostatica. Jullie zijn in week 3.6 bij het vak electromagnetisme doorgegaan met de magnetostatica. Deze opdracht gaat in op het simuleren van deze magnetostatica.
#
# Je werkt bij deze opdracht in teams die wij indelen. Zoek op Brightspace op met wie je samenwerkt en leg via email contact. Maak goede afspraken over hoe je samen gaat werken.
#
# De opdracht bestaat uit de volgende sub-onderdelen:
# 1) Afleiden van een analytische vergelijking
# 2) Criteria opstellen
# 3) Simuleren om de grenzen van jullie ontwerpparameters te bepalen
# 4) Numeriek berekenen van het magneetveld
# 5) Numeriek berekenen van het magneetveld van een solenoide
# 6) Bereken krachtrespons van een kracht actuator
# 7) Beoordeling van de criteria
#
# De opdracht wordt volledig online gedaan, er zullen hiervoor dus ook geen specifieke werkcolleges voor zijn ingeroosterd. Als jullie vragen hebben kunnen jullie die mailen naar het DEF e-mailadres: DEF-TNW@tudelft.nl. Deze opdracht wordt in week 3.9 beoordeeld en herkansingen zijn in week 3.10, zie de studiehandleiding voor details.
#
# Technische Instructies:
# - Download de zip map die op brightspace staat en unzip deze.
# - Creëer een nieuwe branch in je Github repo voor deze opdracht.
# - Plaats de geunzipte map op de juiste plek in jouw branch, zoals in de handleiding op brightspace staat.
# - Nodig je teamgenoot uit als collaborateur op jouw repo.
#
# Onderwijs Instructies:
# - Beantwoord de vragen die in dit notebook voor komen direct in dit notebook.
# - Als je iets moet printen op het scherm als antwoord op een vraag, doe dit op een gestructureerde manier met als dat relevant is de eenheid erbij, zoals je geleerd is bij het Inleidend Practicum.
# - Vermijd 'hardcoden' waar mogelijk.
# - Probeer de voorbeeld code te begrijpen.
# - Op een aantal plekken zijn voorbeelden gegeven of bepaalde numerieke methodes sterk versimpeld. Deze code kunnen reprocuderen is niet een leerdoel van dit vak en zal later in de opleiding voorkomen. Denk hierbij aan het integreren en differentieeren, probeer deze dingen wel te begrijpen.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DEF-D opdracht 2: Ontwerp een solenoïdale krachtactuator
#
#
# <img align="right" style="margin-left:15px" src="figures\solenoidactuator.png" width="600">
#
#
# In deze ontwerpopdracht ga je een krachtactuator ontwerpen gebaseerd op een solenoïde en een permanente magneet. Deze lineaire krachtactuatoren worden gebruikt om bijvoorbeeld kleppen en afsluiters elektronisch te bedienen. Ook komen ze in vele huidshoudelijk apparaten voor. Hiernaast zie je een plaatje van een krachtactuator van de buitenkant en van de doorsnede. De krachtactuator bestaat uit een solenoïde (spoel), dat is een spiraalvormige stroomkring waar een stroom doorheen loopt. Zoals je weet kan je met een solenoide een redelijk homogeen veld maken als de solenoide lang en smal is. In de solenoïde  zit een cilinder,een zogeheten plunjer, die kan schuiven in de solenoïde. De plunjer is verbonden met het object dat je wilt bewegen. De plunjer kan gemaakt zijn van een magnetisch materiaal met een hoge magnetische permeabiliteit of van een permanente magneet. In dit voorbeeld kiezen we voor een plunjer van magnetiseerbaar materiaal.
#
# Voor het ontwerpen van de actuator gaan we eerst de kracht van de actuator uitrekenen met behulp van analytische theorie. We nemen eerst aan dat de solenoïde ideaal is en leiden daarvoor een analytische vergelijking af. Nadat we een eerste ontwerp hebben gemaakt gebaseerd op de analytische oplossing gaan we simuleren hoe goed onze krachtactuator echt werkt en of we het ontwerp nog kunnen verbeteren. Daar gaan we!
#
# ## Deel 1: afleiden van een analytische vergelijking
#
# Hier onder ze je een detaildoorsnede van de solenoïde. De solenoïde heeft een lengte $L_s$, $N$ wikkelingen, een straal $r_s$ en er loopt een constante stroom $I$ door de draad. De plunjer is een afstand $z_p$ in de solenoide geschoven en moet over een zo groot mogelijke afstand een kracht uitoefenen. Een ideale solenoïde heeft binnenin een constant veld dat overal langs de as is gericht, buiten de solenoïde is het veld nul. Daarnaast nemen we aan dat het magnetisch materiaal homogeen en lineair is en een relatieve permeabiliteit $\mu_r$ heeft.
#
# <center>
# <img src="figures\solenoidactuatorgraph.png" width="1000">
# </center>
#
# **Opdracht 1**
#
# a. Pas de wet van Ampère toe voor het $\mathbf{H}$-veld met gebruik van contour $\cal C$.\
# b. Leidt een vergelijking af voor het $\mathbf{B}$-veld als functie van $z_p$.\
# c. Voldoet jouw afleiding aan de randvoorwaarden voor het H en B veld?

# %% [markdown]
# <img align="right" style="margin-left:15px" src="figures\afleiding.jpeg" width="600">

# %% [markdown]
# Het randveld van de solenoïde zal de plunjer de solenoïde intrekken. Echter, het berekenen van de randvelden is een hele klus, we zullen dit later doen. We gebruiken hier een aanpak soortgelijk aan die voor een dielektricum in een condensator. Allereerst berekenen we de totale energie van het systeem met behulp van $W = \frac{1}{2} \int_{\cal V} \mathbf{H} \cdot \mathbf{B} \, d\tau $. Daarna bepalen we de kracht op de plunjer door de afgeleide van de energie naar de positie te nemen. We nemen aan dat de plunjer dezelfde straal heeft als de solenoide, $r_s$.
#
# **Opdracht 2**
#
# Bereken de totale hoeveelheid energie in de solenoïde als functie van $z_d$ door de veldenergie over het volume van de solenoïde te integreren met behulp van bovenstaande vergelijking.

# %% [markdown]
# <img align="right" style="margin-left:15px" src="figures\afleiding.jpeg" width="600">
#
# $$W(z_p) = \frac{1}{2} \pi r_s^2 \left(\frac{N}{L_s}\right)^2 I^2 \left[ (\mu_0 - \mu)z_p + (\mu_0 + \mu)\frac{L_s}{2} \right]$$

# %% [markdown]
# Zoals je wellicht ziet uit je afleiding is de energie van de plunjer groter als de plunjer er geheel uit is en kleiner als de plunjer er geheel in is. De afgeleide van de energie naar de positie $z_p$ geeft dan ook een kracht die de plunjer naar buiten beweegt. Dit is fysisch niet wat er gebeurd. Wat we in de afleiding niet hebben meegenomen is de energie die het kost om de stroom te laten stromen. Het veranderende magneetveld veroorzaakt door het naar binnen bewegen van de magneet (wet van Faraday) geeft een stroom tegengesteld aan de aangelegde stroom, de stroombron moet dan dus meer vermogen gaan leveren om de stroom op gang te houden. Als we dit effect wel meenemen blijkt dat de grootte van de kracht gelijk is, maar dat deze dan de plunjer de solenoide intrekt. We gaan hier niet verder op in.
#
#
# **Opdracht 3**
#
# Bereken de kracht van de spoel op de plunjer.

# %% [markdown]
# <img align="right" style="margin-left:15px" src="figures\afleiding2.jpeg" width="600">

# %% [markdown]
# ## Deel 2: Criteria opstellen
#
# Jullie gaan nu een magnetische kracht actuator ontwerpen hiervoor gaan jullie nu een ontwerpcyclus doorlopen.
#
# **Opdracht 4**
#
# a. Bedenk en schets vijf toepassingen van een kracht actuator.\
# b. Kies uit deze toepassingen minimaal 2 toepassingen voor een kracht actuator om verder mee door te rekenen.

# %% [markdown]
# Plaats hier een foto van jullie vijf schetsen met uitleg over wat er te zien is.
#
# ik kies het flipperkast schietertje en het kluisslot
#
# <img align="right" style="margin-left:15px" src="figures\schetsen.jpeg" width="600">

# %% [markdown]
# **Opdracht 5**
#
# We gaan nu verder kijken naar de criteria van jullie kracht actuatoren. Wij hebben alvast twee essentiele criteria vastgesteld zodat we hier later in de opdracht mee verder kunnen rekenen. Hieronder zijn 4 veelgebruikte stroombronnen benoemd die jullie gaan gebruiken voor een van de criteria.
#
# | Spanningsbron             | Stroomsterkte | Voltage | draad dikte van de spoel |
# |:--------------------------|:--------------|:--------|:-------------------------|
# | Arduino uno digital pin   | 40 mA         | 5 V     | 0.05 mm                  |
# | 9 Volt batterij           | 500 mA        | 9 V     | 0.1  mm                  |
# | 40 Watt telefoon oplader | 2 A           | 20 V    | 0.2 mm                   |
# | Een auto batterij         | 180 A         | 12 V    | 1.5 mm                   |
#
#
# a. Kies een van de hierboven benoemde stroombronnen om te gebruiken in jullie ontwerp. \
# b. Gebruik de methode uit het college 'schattend rekenen' om voor elke toepassing de minimale kracht die de actuator moet kunnen leveren voor jullie toepassing te bepalen.\
# c. Denk na over wat de straal van jullie actuator mag zijn. \
# d. Bedenk nog 1 ander criterium per toepassing.

# %% [markdown]
# a. Gekozen stroombron:Voor een snelle, krachtige stoot in een flipperkast hebben we flink wat vermogen nodig. We kiezen hiervoor de 40 Watt telefoonoplader (2 A, 20 V).
#
# b. Minimale kracht (schattend rekenen):We nemen een standaard stalen flipperkastbal met een massa ($m$) van 0,08 kg. Om het balletje goed over het speelveld te laten rollen, willen we een eindsnelheid ($v$) van ongeveer 2 m/s bereiken. De slag schatten we op 0,03 m. Eerst berekenen we de benodigde versnelling ($a$) met de bewegingsvergelijking
# $$v^2 = 2 \cdot a \cdot s$$:$$a = \frac{v^2}{2 \cdot s} = \frac{2^2}{2 \cdot 0,03} \approx 66,7 \text{ m/s}^2$$
# De benodigde kracht is dan volgens de tweede wet van Newton:
# $F = m \cdot a = 0,08 \cdot 66,7 \approx 5,3 \text{ N}$
# Met een veiligheidsmarge is de ontwerpeis voor de minimale kracht 6 N.
#
# c. Straal van de actuator:Omdat de spoel een fysieke klap moet uitdelen en een redelijke stroom te verwerken krijgt, mag deze niet te iel zijn. Een straal van 0,01 m tot 0,015 m (1 tot 1,5 cm) is een geschikte en robuuste ontwerpparameter.
#
# d. Extra criterium:Minimale slaglengte. De actuator moet zijn kracht over een minimale afstand van 5 cm kunnen overbrengen. Als de plunjer te kort is, verliest hij te snel contact met het balletje en wordt de eindsnelheid niet gehaald.
#
# a. Gekozen stroombron:Dit type slot moet compact en onafhankelijk werken, bijvoorbeeld in een kleedkamer of hotel. We kiezen hiervoor de 9 Volt batterij (500 mA).
#
# b. Minimale kracht (schattend rekenen):De plunjer hoeft geen voorwerpen weg te schieten, maar trekt een stalen pinnetje naar binnen tegen de weerstand van een terughaalveertje in (dit veertje zorgt dat de kluis zonder stroom veilig op slot valt).Stel dat we een veiligheidsveertje gebruiken met een veerconstante ($C$) van 150 N/m. De afstand ($u$) die de pin moet afleggen om te ontgrendelen is ongeveer 0,01 m (1 cm).De veerkracht die we moeten overwinnen is:
# $F = C \cdot u = 150 \cdot 0,01 = 1,5 \text{ N}$
# Als we hier wat mechanische wrijving in het slotmechanisme bij optellen (geschat op 0,5 N), komen we uit op een ontwerpeis voor de minimale trekkracht van 2 N.
#
# c. Straal van de actuator:Een kluisslot wordt ingebouwd in een deur of smalle rand en moet dus erg compact zijn. Een geschatte straal van 0,005 m tot 0,008 m (5 tot 8 mm) is hiervoor realistisch.
#
# d. Extra criterium:Energie-efficiëntie / warmteontwikkeling. Omdat het systeem op een batterij werkt en soms enkele seconden open moet blijven staan terwijl de gebruiker de deur opent, mag de spoel de batterij niet direct leegtrekken of te heet worden bij langdurig zeg 5 minuten gebruik.

# %% [markdown]
# ## Deel 3: Simuleren om de grenzen van jullie ontwerpparameters te bepalen
#
# Jullie zullen nu simulaties gaan uitvoeren om de grenzen van jullie ontwerpparameters op te zoeken. Dit doen jullie voor jullie twee gekozen toepassingen en een deuractuator. Deze deuractuator moet een deur van het slot afhaalen door een kracht van 40 N uit te oefenen, gebruikt een 9 volt batterij als stroombron, de plunjer is gemaakt van ijzer en de straal van de actuator is 0.01 m.
#
# **Opdracht 6**
#
# Zet de relevante parameters in een Python script en maak een Python functie die met behulp van de wet van Ohm de maximale draadlengte uitrekent. Print de maximale draadlengte bij het uitvoeren van het script.

# %% [markdown]
# Plaats in deze cel een png met jullie eventuele analytische uitwerkingen.

# %%
rho_koper = 1.68e-8 

def max_draadlengte(V, I, d_draad):

    R_max = V / I
    
    # Oppervlakte van de doorsnede van de draad (A = pi * r^2)
    r_draad = d_draad / 2.0
    A_draad = np.pi * (r_draad**2)
    
    # Maximale lengte draad
    L_max = (R_max * A_draad) / rho_koper
    
    return L_max

L_deur = max_draadlengte(9, 0.5, 0.0001)
print(f"Maximale draadlengte deuractuator (9V batterij): {L_deur:.2f} meter")

L_flipper = max_draadlengte(20, 2.0, 0.0002)
print(f"Maximale draadlengte flipperkast (40W lader): {L_flipper:.2f} meter")

L_kluis = max_draadlengte(9, 0.5, 0.0001)
print(f"Maximale draadlengte kluisslot (9V batterij): {L_kluis:.2f} meter")
# Out:
# Maximale draadlengte deuractuator (9V batterij): 8.41 meter
# Maximale draadlengte flipperkast (40W lader): 18.70 meter
# Maximale draadlengte kluisslot (9V batterij): 8.41 meter

# %% [markdown]
# **Opdracht 7**
#
# Leidt een vergelijking af voor het minimale aantal wikkelingen $N$ die je nodig hebt om het gewicht op te kunnen tillen. Voeg je afleiding als png toe aan je notebook.

# %% [markdown]
# <img align="right" style="margin-left:15px" src="figures\afleiding3.jpeg" width="600">

# %% [markdown]
# We gaan nu de ontwerpvrijheid verkennen. Gegeven de materiaalparameters en de eigenschappen van de stroombron kunnen we de verhouding tussen de lengte en de straal van de solenoide kiezen.
#
# **Opdracht 8**
#
# Schrijf een enkele Python functie die het minimum en maximum aantal wikkelingen uitrekent als functie van $L_s$, $r_s$, $r_d$ en $I$. De functie moet de volgende voorwaarden controleren
# 1) Het minimum aantal wikkelingen wordt gegeven door de hiervoor afgeleide relatie van het aantal wikkelingen om de benodigde kracht te genereren.
# 2) Het maximum aantal wikkelingen wordt gegeven door de draaddikte $r_d$ en de lengte $L_s$
# 3) Het maximum aantal wikkelingen wordt gegeven door de draadlengte en de straal van de solenoide
# 4) Het maximum aantal wikkelingen moet groter zijn dan het minimum aantal wikkelingen
#
# Het maximum aantal wikkelingen is de kleinste van voorwaarde 2) en 3). Geef een foutmelding als het minimum aantal windingen groter is dan het maximum aantal windingen.

# %% [markdown]
# Plaats hier een png met jullie eventuele analytische afleiding.

# %%
import numpy as np

def aantal_wikkelingen(L_s, r_s, r_d, I, V, F_min, mu_r):

    mu_0 = 4 * np.pi * 1e-7
    rho_koper = 1.68e-8
    
    N_min = (L_s / I) * np.sqrt((2 * F_min) / (mu_0 * mu_r * np.pi * (r_s**2)))
    
    N_max_1 = L_s / (2 * r_d)
    
    L_max_draad = (V * np.pi * (r_d**2)) / (I * rho_koper)
    # Omtrek van één wikkeling is 2 * pi * r_s
    N_max_2 = L_max_draad / (2 * np.pi * r_s)
    
    N_max = min(N_max_1, N_max_2)
    
    if N_min > N_max:
        print(f"Fout: Dit ontwerp is niet haalbaar! N_min ({N_min:.1f}) is groter dan N_max ({N_max:.1f}).")
        N_min = float('NaN')
        N_max = float('NaN')
        
    return N_min, N_max

# Stel we testen de deuractuator: L=0.05m, r_spoel=0.01m, r_draad=0.00005m, I=0.5A, V=9V, F=40N, mu_r=1000
print(aantal_wikkelingen(0.05, 0.01, 0.00005, 0.5, 9, 40, 1000))
# Out:
# Fout: Dit ontwerp is niet haalbaar! N_min (1423.5) is groter dan N_max (133.9).
# (nan, nan)

# %% [markdown]
# Een parameter plot geeft ons inzicht in de haalbaarheid van het idee. In dit geval willen we kijken naar het mogelijke aantal wikkelingen en de lengte van onze solenoide. Hieronder staat een voorbeeld van code die een voorbeeld plot creëert met minimale eis $y=x$ en de maximale eis $y=2x$.

# %%
x = np.linspace(0,10,100)
y_min = x # Minimale eis
y_max = 2*x # Maximale eis

plt.fill_between(x,y_min,y_max) # De ruimte tussen de eisen vullen
plt.title("Voorbeeld parameter plot")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Opdracht 9**
#
# Maak een parameterplot met behulp van bovenstaand gedefinieerde functie voor de drie solenoideactuatoren voor $L_s$ tussen 0 en 1 m in 50 stappen. Een parameter plot ziet er hier uit als een plot tussen het minimale aantal wikkelingen en het maximaal aantal wikkelingen.

# %%
# Maak een array voor L_s van 0 tot 1 meter in 50 stappen
Ls_array = np.linspace(0.01, 1.0, 50)

N_min_deur, N_max_deur = [], []
N_min_flipper, N_max_flipper = [], []
N_min_kluis, N_max_kluis = [], []

mu_r_ijzer = 3000

for L in Ls_array:
    min_d, max_d = aantal_wikkelingen(L, 0.01, 0.00005, 0.5, 9, 40, mu_r_ijzer)
    N_min_deur.append(min_d)
    N_max_deur.append(max_d)
    
    min_f, max_f = aantal_wikkelingen(L, 0.015, 0.0001, 2.0, 20, 6, mu_r_ijzer)
    N_min_flipper.append(min_f)
    N_max_flipper.append(max_f)
    
    min_k, max_k = aantal_wikkelingen(L, 0.006, 0.00005, 0.5, 9, 2, mu_r_ijzer)
    N_min_kluis.append(min_k)
    N_max_kluis.append(max_k)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.fill_between(Ls_array, N_min_deur, N_max_deur, color='blue', alpha=0.3)
plt.plot(Ls_array, N_min_deur, 'b--', label='N min')
plt.plot(Ls_array, N_max_deur, 'b-', label='N max')
plt.title("Parameterplot: Deuractuator")
plt.xlabel("Lengte solenoïde L_s (m)")
plt.ylabel("Aantal wikkelingen N")
plt.legend()

plt.subplot(1, 3, 2)
plt.fill_between(Ls_array, N_min_flipper, N_max_flipper, color='red', alpha=0.3)
plt.plot(Ls_array, N_min_flipper, 'r--', label='N min')
plt.plot(Ls_array, N_max_flipper, 'r-', label='N max')
plt.title("Parameterplot: Flipperkast")
plt.xlabel("Lengte solenoïde L_s (m)")
plt.legend()

plt.subplot(1, 3, 3)
plt.fill_between(Ls_array, N_min_kluis, N_max_kluis, color='green', alpha=0.3)
plt.plot(Ls_array, N_min_kluis, 'g--', label='N min')
plt.plot(Ls_array, N_max_kluis, 'g-', label='N max')
plt.title("Parameterplot: Kluisslot")
plt.xlabel("Lengte solenoïde L_s (m)")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Fout: Dit ontwerp is niet haalbaar! N_min (164.4) is groter dan N_max (100.0).
# Fout: Dit ontwerp is niet haalbaar! N_min (496.5) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (828.6) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (308.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (1160.7) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (432.6) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (1492.8) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (556.3) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (1824.9) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (680.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (2157.0) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (803.9) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (2489.1) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (927.6) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (2821.2) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (1051.4) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (3153.3) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (203.5) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1175.2) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (3485.4) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (225.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1298.9) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (3817.5) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (246.4) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1422.7) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (4149.6) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (267.9) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1546.5) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (4481.7) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (289.3) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1670.2) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (4813.8) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (310.7) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1794.0) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (5145.9) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (332.2) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (1917.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (5478.0) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (353.6) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2041.5) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (5810.1) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (375.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2165.3) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (6142.2) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (396.5) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2289.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (6474.3) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (417.9) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2412.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (6806.4) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (439.4) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2536.6) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (7138.6) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (460.8) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2660.4) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (7470.7) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (482.2) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2784.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (7802.8) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (503.7) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (2907.9) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (8134.9) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (525.1) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3031.7) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (8467.0) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (546.5) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3155.5) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (8799.1) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (568.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3279.2) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (9131.2) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (589.4) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3403.0) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (9463.3) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (610.9) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3526.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (9795.4) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (632.3) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3650.5) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (10127.5) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (653.7) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3774.3) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (10459.6) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (675.2) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (3898.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (10791.7) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (696.6) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4021.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (11123.8) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (718.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4145.6) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (11455.9) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (739.5) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4269.4) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (11788.0) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (760.9) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4393.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (12120.1) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (782.3) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4516.9) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (12452.2) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (803.8) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4640.7) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (12784.3) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (825.2) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4764.4) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (13116.4) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (846.7) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (4888.2) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (13448.5) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (868.1) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5012.0) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (13780.6) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (889.5) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5135.7) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (14112.7) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (911.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5259.5) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (14444.8) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (932.4) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5383.3) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (14776.9) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (953.8) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5507.0) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (15109.0) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (975.3) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5630.8) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (15441.1) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (996.7) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5754.6) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (15773.2) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (1018.2) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (5878.3) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (16105.3) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (1039.6) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (6002.1) is groter dan N_max (223.2).
# Fout: Dit ontwerp is niet haalbaar! N_min (16437.5) is groter dan N_max (133.9).
# Fout: Dit ontwerp is niet haalbaar! N_min (1061.0) is groter dan N_max (198.4).
# Fout: Dit ontwerp is niet haalbaar! N_min (6125.9) is groter dan N_max (223.2).

# %% [markdown]
# **Opdracht 10**
#
# Maak voor elke actuator een keuze voor de lengte van de spoel, de straal van de spoel en de lengte van de draad.

# %% [markdown]
# 1. Deuractuator
# Zoals te zien is in de parameterplot, is de grafiek leeg. Dit betekent dat N_min groter is dan N_max voor alle lengtes. Het is met een stroom van 0,5 A en deze draaddikte fysiek onmogelijk om genoeg wikkelingen op de spoel te krijgen om de vereiste 40 N te halen.
#
# Conclusie: Geen haalbaar ontwerp met deze parameters. (We komen hier bij Opdracht 17 op terug).
#
# 2. Eigen toepassing 1: Flipperkast
# We kiezen een punt veilig in het midden van het rode werkbare gebied. (van n = 50 tot n = 175)
#
# Gekozen lengte spoel (L_s): 0.05 meter (5 cm)
#
# Straal van de spoel (r_s): 0.015 meter
#
# Aantal wikkelingen (N): 100
#
# Resulterende draadlengte: 100 * 2 * π * 0.015 ≈ 9.4 meter
#
# 3. Eigen toepassing 2: Kluisslot
# We kiezen een punt in het midden van het groene werkbare gebied.
#
# Gekozen lengte spoel (L_s): 0.02 meter (2 cm)
#
# Straal van de spoel (r_s): 0.006 meter
#
# Aantal wikkelingen (N): 140
#
# Resulterende draadlengte: 140 * 2 * π * 0.006 ≈ 5.3 meter

# %% [markdown]
# Bovenstaande analytische berekening is een goede start voor het ontwerp en geeft aan welke parameters je kan optimaliseren. Echter in een echte solenoide zullen er allerlei niet ideale effecten een rol spelen. Zo zal het veld in de solenoide niet constant zijn (het is geen oneindig lange solenoide) en zijn er randvelden aan de uiteinden van de solenoide. We zullen nu de kracht-afstand relatie van de solenoide krachtactuator uitrekenen. Deze kan dan verder geoptimaliseerd worden om de kracht-uitwijking relatie zo lineair mogelijk te maken.

# %% [markdown]
# ## Deel 4: Numeriek berekenen van het magneetveld van een rechte stroomdraad
#
# <img align="right" style="margin-left:15px" src="figures\wiregeometry.jpeg" width="300">
#
# Omdat we in ons ontwerp een stroombron gebruiken met een aangelegde stroom voeren we de berekeningen uit met het $\mathbf{H}$-veld. De analytische oplossing voor het $\mathbf{H}$-veld om een oneindig lange stroomdraad is het met meest eenvoudige voorbeeld voor het berekenen van het magnetisch veld en het toepassen van de wet van Ampere. In cilindrische coordinaten wordt het magneetveld op afstand $s$ veroorzaakt door stroom $I$ gegeven door (zie Griffiths blz. 282, voorbeeld 6.2)
# $$
#     \mathbf{B} =\frac{I}{2 \pi s} \hat{\boldsymbol{\phi}} \, .
# $$
#
#
# Alleen in de meest eenvoudige stroomgeometrieën kunnen we het magneetveld analytisch berekenen. In meer complexe stroomgeometrieën moeten we numerieke methoden gebruiken om het magneetveld te berekenen. In deze opdracht willen we een numerieke methode ontwikkelen voor een complexe stroomgeometrie, maar gebruiken we het voorbeeld van de oneindig lange stroomdraad om onze numerieke methode te testen. We gaan het magneetveld berekenen met de wet van Biot-Savart (zie Griffiths blz. 222, Vgl. 5.34) maar dan voor het $\mathbf{H}$-veld
#
# $$
#     \mathbf{H}(\mathbf{r}) = \frac{1}{4 \pi} I \int \frac{d \mathbf{l}' \times \widehat{(\mathbf{r} - \mathbf{r}')}}{|\mathbf{r} - \mathbf{r}'|^2} \, .
# $$
#
# De wet van Biot-Savart laat zien dat het magneetveld wordt gegeven door een som over lijnelementen $d\mathbf{l}$ met bijdrage
#
# $$
#     d\mathbf{H}(\mathbf{r}) = \frac{1}{4 \pi} I  \frac{d \mathbf{l}' \times \widehat{(\mathbf{r} - \mathbf{r}')}}{|\mathbf{r} - \mathbf{r}'|^2} \, .
# $$
#
# **Opdracht 11**
#
# Schrijf een Python funktie met als invoer de variabelen:
# * een array die de veldpositie $\mathbf{r}$ aangeeft
# * een array die de de bronpositie $\mathbf{r}'$ aangeeft
# * een array die de lengte $d\mathbf{l}$ aangeeft
#
# De functie moet het magneetveld van een lijnelement $d\mathbf{l}$ berekenen. Gebruik voor het uitrekenen van het uitproduct de numpy $\verb|cross|$ functie en de hierboven gegeven formule voor $d\mathbf{H}$.
#
# Bereken met deze functie alle componenten van het magneetveld voor een veldpositie op $x=0.1$ m voor een stroombronelement in de oorsprong met een stroom van 6 A een lengte van $d\mathbf{l}$ gelijk aan $L/64$. Print het analytische en numerieke antwoord naar de command line en controleer dat het magneetveld gelijk is aan $\mathbf{H} =  0.00746 \hat{\mathbf{y}}$ A/m is.

# %%
L_draad = 0.1

dl=np.array([0, 0, L_draad/64])
r_field=np.array([0.1, 0, 0])
r_source=np.array([0, 0, 0])
I = 6
L_draad = 0.1


def field_current_element(r_field, r_source, dl):
    r_vec = r_field - r_source 
    r_mag = np.linalg.norm(r_vec)
    r_hat = r_vec / r_mag
    cross_product = np.cross(dl, r_hat)
    dH = (I / (4 * np.pi)) * (cross_product / (r_mag**2))
    return dH

analytical_answer=(I/4/np.pi)*(L_draad/64)/np.sum((r_field-r_source)**2) # een veld elementje.
print('The analytical answer is ' + str(analytical_answer) + ' A/m in the y-direction')

print('The numerical answer is is ' + str(field_current_element(r_field, r_source, dl)) + ' A/m')
# Out:
# The analytical answer is 0.07460387957432593 A/m in the y-direction
# The numerical answer is is [0.         0.07460388 0.        ] A/m

# %% [markdown]
# Nu gaan we met behulp van de numerieke implementatie van de wet van Biot-Savart het magneetveld uitrekenen in het vlak loodrecht op de draad. We nemen daarom een eindige lengte van de draad en verdelen dit in kleine stukken met lengte $d\mathbf{l}$. Daarna integreren we over de gehele lengte door de bijdrage van al deze stukken op te tellen en zo het magneetveld te bepalen. Voor het correct uitvoeren van deze numerieke integratie is het van belang dat we en een lang genoeg stuk draad nemen en dat we dit in genoeg kleine delen ophakken.
#
# **Opdracht 12**
# * Creëer een array met de veldcoordinaat $\mathbf{r}$.
# * Bereken een array met alle contributies $dH$ op $r=(x,y,z)=(0.1, 0, 0)$ m.
# * Plot de contributies tegen de locatie van de bijbehorende bron.
# * Bereken het $H$ veld door over alle contributies te someren.
# * Print een regel met het numerieke antwoord en vergelijk dit met het analytische antwoord.
# * Bestudeer hoe de bijdragen varieren voor de verschillende locaties en hoe groot L en het aantal stappen moet zijn om een numeriek correct resultaat te krijgen.
#
# Deze opdracht kan ook gemaakt worden met het gebruik van for loops, De akauze voor methode is aan jullie.

# %%
r_field=np.array([0.1, 0, 0])
D = 100
dl = np.array([0, 0, L_draad/D])
r_source = np.array([0, 0, -L_draad/2]) # om ervoor te zorgen dat de numerieke berekening klopt moeten we symmetrische rondom het veld element de berekeningen uitvoeren

dH_array = []
r_source_array = []

for i in range(D): 
    dH = field_current_element(r_field, r_source, dl)
    dH_array = np.append(dH_array, dH[1])
    r_source = r_source + dl
    r_source_array = np.append(r_source_array, r_source[2])

plt.figure(figsize=(10,5))
plt.plot(r_source_array, dH_array)
plt.xlabel('z (m)')
plt.ylabel('dH (A/m)')
plt.show()

H_field = np.sum(dH_array)
print('Het veld op r_field is ' + str(H_field) + ' A/m')

H_field_analytisch = I / (2 * np.pi *0.1)

print('Het veld op r_field volgens de analytische formule is ' + str(H_field_analytisch) + ' A/m')
# Out:
# Het veld op r_field is 4.2705069305700425 A/m
# Het veld op r_field volgens de analytische formule is 9.549296585513721 A/m

# %% [markdown]
# ### Deel 5: Numeriek berekenen van het magneetveld van een solenoide
#
# We gaan nu het magneetveld van onze solenoide uitrekenen. Deze solenoide is een draad die om een cylinder gewikkeld is. Hieronder is een functie gegeven die de draad van een solenoide parametriseert. Deze parametrisatie gaan jullie gebruiken in combinatie met Biot-Savart om het H veld rond de solenoide te berekenen.

# %%
def parametrisatie(N,r_sol,aantal_omwentelingen,L_sol):
    t=np.linspace(0, 1, N)
    x = r_sol * np.cos(2 * np.pi * aantal_omwentelingen*t) # x coordinaten
    y = r_sol * np.sin(2 * np.pi * aantal_omwentelingen*t) # y coordinaten
    z = L_sol* t - L_sol/2  # z componenten
    return x,y,z

# %% [markdown]
# **Opdracht 13**
#
# Bereken het traject van een stroomdraad met een straal van $r_{sol}$. De solenoide met lengte $L_{sol}$ is gecentreerd op de oorsprong met de cilinderas langs de $z$-as. Doe dit door de hierboven gegeven functie te gebruiken.
#
# a. Bereken het aantal omwentelingen van je draad, hierbij mag je aannemen dat de omtrek een cirkel is (in feite is het een ellips, maar omdat de windingen zo dicht op elkaar zitten is het vrijwel een cirkel).\
# b. Bereken de $x$, $y$ en $z$ coordinaten.\
# c. Bereken de spoed, in eenheden van aantal omwentelingen per meter, en print dit.

# %%
l_draad = 5.3      # Lengte draad in meters
r_sol = 0.006      # Straal solenoide in meters
L_sol = 0.02       # Lengte solenoide in meters
N = 5000

aantal_omwentelingen = l_draad / (2 * np.pi * r_sol)

x, y, z = parametrisatie(N, r_sol, aantal_omwentelingen, L_sol)

spoed = l_draad / (N * (L_sol / N)) # Spoed = totale lengte draad / totale hoogte van de solenoide
print(f"de solenoide heeft {spoed:.4f} omwentelingen")

# Enkele plots
ax=plt.figure().add_subplot(projection='3d')
plt.title('Traject van de draad van de solenoide')
plt.plot(x, y, z, '-r', linewidth=0.1)
ax.set_box_aspect(aspect=None, zoom=0.8)
ax.set_xlabel('x (m)'), ax.set_ylabel('y (m)'), ax.set_zlabel('z (m)')

spoed = aantal_omwentelingen/L_sol
print(f"Spoed: {spoed:.2f} windingen per meter")
# Out:
# de solenoide heeft 265.0000 omwentelingen
# Spoed: 7029.34 windingen per meter

# %% [markdown]
# Het veld in een oneindig lange solenoide wordt gegeven door $\mathbf{H} = n I \hat{\mathbf{z}}$, met $n$ de spoed van de draad, en $I$ de stroom.
#
# **Opdracht 14**
#
# Bereken het veld in het midden van de solenoide en vergelijk het met het analytische antwoord voor een oneindig lange solenoide. Verhoog $N$ net zo lang tot jullie antwoord convergeert naar het analytisch antwoord.
# * Denk na over wat dl betekent en hoe jullie deze zou berekenen.
# * Bereken met de functie die jullie eerder geschreven hebben de contributies aan het $H$-veld en sommeer deze.

# %%
# analytisch veld
H_analytisch = I * spoed
print(I, spoed)
# veldpunt in het midden
r0 = np.array([0.0, 0.0, 0.0])

# dl
dx = np.diff(x)
dy = np.diff(y)
dz = np.diff(z)
dl = np.vstack((dx, dy, dz)).T #maakt matrix met dl vectoren als rijen

# posities van draadsegmenten
r = np.vstack((x[:-1], y[:-1], z[:-1])).T

# R = r0 - r
R = r0 - r
R_norm = np.linalg.norm(R, axis=1)

# eenheidsvector R_hat
R_hat = R / R_norm[:, None]

# Biot–Savart: dl × R_hat / R^2
cross = np.cross(dl, R_hat)
H_contrib = cross / (R_norm**2)[:, None]

# totale H
H = (I / (4*np.pi)) * np.sum(H_contrib, axis=0)

print("H numeriek:", H)
print("H_z numeriek:", H[2])
print("H analytisch:", H_analytisch)

H = spoed * I
r_field = np.array([0, 0, 0]) # veldpunt in het midden van de solenoide
H_array = np.array([])

for i in range(N-1):
    dl = np.array([x[i+1]-x[i], y[i+1]-y[i], z[i+1]-z[i]])
    dH = -field_current_element(np.array([x[i], y[i], z[i]]), r_field, dl)
    H_array = np.append(H_array, dH)


print(np.sum(H_array))
print(H)
# Out:
# 6 7029.343319892044
# H numeriek: [9.36497879e+00 2.60513679e+00 3.59777626e+04]
# H_z numeriek: 35977.7625895214
# H analytisch: 42176.059919352265
# 35989.73270509792
# 42176.059919352265

# %% [markdown]
# ### Deel 6: Bereken krachtrespons van een kracht actuator
# Omdat onze solenoide niet oneindig lang is zal het veld in de solenoide niet uniform zijn en ook niet op alle plaatsen exact langs de as gericht zijn.
#
# **Opdracht 15**
#
# Bereken de $z$-component van het $\mathbf{H}$-veld op de as van de solenoide over het interval $z \in [0, 1.5L_s]$ in 25 stappen. Je moet nu dus op elk veld-punt met behulp Biot-Savart de bijdragen van alle stroomelementen integreren. Maak een grafiek van de $z$-component van het $\mathbf{H}$-veld tegen $z$.

# %%
n_ax = 25
z_ax = np.linspace(0, 1.5*L_sol/2, n_ax)
H_ax = np.zeros((n_ax,1))
I = 6.0
N = 5000

for i_field in range(n_ax):
    print(f"\rIfield =  {i_field}", end="")

    r_field = np.array([0.0, 0.0, z_ax[i_field]])
    Hsimulated = np.array([0.0, 0.0, 0.0], dtype='float64')

    for i_source in range(N-1):

        r_source = np.array([x[i_source], y[i_source], z[i_source]])
        dl_vec   = np.array([dx[i_source], dy[i_source], dz[i_source]])

        # gebruik jouw functie
        Hsimulated += field_current_element(r_field, r_source, dl_vec,)

    H_ax[i_field,0] = Hsimulated[2]


# ideaal veld
H_veld_ideaal = H_analytisch * np.ones(n_ax) * (1.0*(z_ax < L_sol/2))

# analytisch eindige solenoide
H_veld_analytisch = (aantal_omwentelingen*I/L_sol/2)*((L_sol/2 - z_ax)/np.sqrt((z_ax - L_sol/2)**2 + r_sol**2) +(L_sol/2 + z_ax)/np.sqrt((z_ax + L_sol/2)**2 + r_sol**2))

plt.figure(figsize=[13,4])
plt.subplot(131)
plt.title('z-component van H-veld')
plt.plot(z_ax, H_veld_ideaal, '-r', label='ideaal')
plt.plot(z_ax, H_veld_analytisch, '-g', label='analytisch')
plt.plot(z_ax, H_ax, '-k', label='simulatie')
plt.xlabel('Afstand langs de as van de solenoide (m)')
plt.ylabel('H-veld (A/m)')
plt.legend()
plt.show()
# Out:
# Ifield =  24

# %% [markdown]
# We gaan de solenoide nu gebruiken voor onze krachtactuator. Daarvoor gaan we opnieuw de energie in het magnetisch veld berekenen, maar nu met het numerieke resultaat voor een eindige lengte solenoide. We gaan hier nu een aantal aannames maken:
# * We nemen aan het veld alleen een $z$-component heeft en niet afhangt van de afstand tot de solenoide as
# * We verwaarlozen de bijdrage aan de energie van het deel van de solenoide gevuld in lucht en integreren alleen het deel van ijzer in het $\mathbf{H}$ veld (dat mag omdat $\mu_r \gg 1$)
# * De plunjer is oneindig lang
#
# Zoals je uit je berekening voor het $\mathbf{H}$ kan zien is de energie van de plunjer in de solenoide groter dan voor de plunjer uit de solenoide. Dit komt doordat we de berekening doen met constante stroom. De verplaatsing van de plunjer geeft echter ook een veranderende flux ($d \Phi/dt$) die een tegen EMF geeft. Deze moet overwonnen worden door de stroombron die de arbeid levert. Het magneetveld verricht dus geen arbeid, dat doet de stroombron! We berekenen dit effect hier niet expliciet, maar nemen $-W$ als energie zodat de kracht de juiste kant op wijst (de solenoide in, dus een kracht in de $-z$ richting).
#
#
# **Opdracht 16**
#
# * Bereken de energie als functie van de afstand van de plunjer in de solenoide met behulp van onderstaand script

# %%
mu_0 = 4 * np.pi * 1e-7

Wz=-0.5*np.pi*r_sol**2*np.cumsum(np.flipud(H_ax)*mu_r_ijzer*mu_0*np.flipud(H_ax))*(z_ax[1] - z_ax[0])

plt.plot(L_sol/2 - z_ax, np.flipud(Wz), '-k')
plt.xlabel('Afstand van plunjer in solenoide (m)'), plt.ylabel('Energie (J)'), plt.grid()
# Out:
# (Text(0.5, 0, 'Afstand van plunjer in solenoide (m)'),
#  Text(0, 0.5, 'Energie (J)'),
#  None)

# %%
force_analytical = -mu_0*mu_r_ijzer*np.pi*r_sol**2*aantal_omwentelingen**2*I**2/2/L_sol**2 # Kracht uitrekenen numeriek
force_numerical=np.diff(Wz, n=1, append=[0])/(z_ax[1] - z_ax[0]) # Kracht uitrekenen

# Plotting the results
plt.plot(L_sol/2 - z_ax, np.flipud(force_numerical), '-o', label='Kracht')
plt.plot(L_sol/2 - z_ax, (-5*9.8)*np.ones(n_ax), '--r', label='Benodigde kracht')
plt.plot(L_sol/2 - z_ax, force_analytical*np.ones(n_ax), '--g', label='Kracht oneindig lange solenoide')
plt.xlabel('Afstand van plunjer in solenoide (m)'), plt.ylabel('Kracht (N)'), plt.grid(), plt.legend()
plt.ylim([-200, 0])
# Out:
# (-200.0, 0.0)

# %% [markdown]
# ### Deel 7: Beoordeling van de criteria
# **Opdracht 17**
#
# Kijk in deze vraag terug naar de criteria die jullie voor de deuractuator hebben opgesteld. Voldoet jullie ontwerp aan alle gestelde criteria?

# %% [markdown]
# ik heb geen waarden gevonden om in de simulatie in te vullen, dus kan het dan moeilijk runnen

# %% [markdown]
# **Opdracht 18**
#
# Voer opdrachten 15 en 16 uit voor jouw eigen gekozen toepassingen.

# %% [markdown]
# -na het invullen van de waarden voor de flipper kast voldoet deze, omdat de blauwe de rode lijn kruist. wl halen we de 100 wikkelingen niet omdat de draad maar 8.7 cm lang mag zijn
# -ook voor het kluisslot werkt het ook hier kruis de blauwe lijn ver over de minimun kracht

# %% [markdown]
# **Opdracht 19**
#
# a. Kijk terug naar de criteria die jullie hebben opgesteld in vraag 5. Hebben jullie nu genoeg informatie om te beoordelen of jullie ontwerp voldoet aan de gestelde criteria, zo nee ontwerp een simpel experiment waarmee jullie het wel zouden uit kunnen voeren.
# b. Beoordeel op basis van de criteria die jullie wel kunnen beoordelen of jullie idee voldoet aan jullie criteria.

# %% [markdown]
# Edit deze cel met jullie antwoorden op vraag 19.

# %% [markdown]
# Controleer eerst nog goed of alles klopt. **Klik boven op `Kernel -> Restart and Run all` en check of er geen errors zijn**. Zorg dat alle benodigde bestanden zijn geüpload in de juiste map en dat de afbeeldingen zichtbaar zijn in het notebook. Je kan nu jouw notebook opslaan, comitten en pushen naar de juiste branch! Maak dan de pull request aan en lever die in in brightspace.

# %% [markdown]
# voor het kluisslot moet en nog etest worden of het warm wordt bij langdurig gebruik verder voldoet het
# de flipperkast schieter voldoet aan alle criteria
# de deuractuator voldoet niet.
